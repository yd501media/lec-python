# %%
for n in range(5):
    print("*"*(n+1))
# Out:
# *
# **
# ***
# ****
# *****

# %%
0, 4: ____*
1, 3: ___**
2, 2: __***
3, 1: _****
4, 0: *****
5, 1: _****
6, 2: __***
7, 3: ___**
8, 4: ____*

# %%
for n in range(9):
    nn = int(abs(10/2 - n - 1))
    print(" "*nn + "*"*int(10/2 - nn))
# Out:
#     *
#    **
#   ***
#  ****
# *****
#  ****
#   ***
#    **
#     *

# %%
for n in range(5):
    print(" "*(5-(n+1))+"*"*(n+1))
# Out:
#     *
#    **
#   ***
#  ****
# *****

# %%
for n in range(5,0,-1):
    print("*"*(n))
# Out:
# *****
# ****
# ***
# **
# *
