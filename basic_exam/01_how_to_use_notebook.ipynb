# %% [markdown]
# # **How to Use Jupyter Notebook**
# Jupyter Notebookは、コードの記述、実行、データの可視化、レポートの作成を1つの環境で行えるツールです。
# Pythonプログラミングやデータ分析に適しており、セル単位でコードやテキストを実行できる柔軟性が特徴です。

# %% [markdown]
# ---
# # Jupyter Notebook 概要
# ##  Jupyter Notebookとは？
# Jupyter Notebookは、Pythonコードの実行環境であり、コードとテキストを同じドキュメント内で編集・実行できます。
# 特にデータ分析や機械学習のプロジェクトに適しており、以下の特徴があります：
# - **インタラクティブな開発** : コードをセル単位で実行でき、結果をすぐに確認できます。
# - **ドキュメント作成** : Markdown形式でのテキスト記述が可能で、コードの説明や結果のまとめを記録できます。
# - **可視化** : グラフや画像を簡単に埋め込めます。

# %% [markdown]
# ---
# # 使用例

# %% [markdown]
# ## セルの種類
# Jupyter Notebookでは、セルはコンテンツを分類して扱いやすくするために以下の3種類に分かれています。

# %% [markdown]
# ### **コードセル**
# - **用途** : Pythonコードを記述し実行するためのセル。
# - **特徴** :
#   - コードを書き込むと、セルを実行することで結果がすぐに表示されます。
#   - 実行後に、計算結果やグラフがセルの直下に表示されます。
#   - Pythonコードを記述し、Shift + Enter で実行できます。
# - **例** :
#   ```python
#   a = 10
#   b = 20
#   print(f"{a+b=}")  # 結果: a+b=30
#   ```

# %% [markdown]
# ### **出力セル**
# - **用途** : コードセルの実行結果を表示する領域。
# - **特徴** :
#   - コードセルを実行すると、自動的に結果がこのセルに表示されます。
#   - 出力結果には数値、文字列、グラフ、エラーなどが含まれます。
# - **例** :
#   - コードセルの実行結果:
#     ```
#     a+b=30
#     ```

# %% [markdown]
# ### **Markdownセル**
# - **用途** : テキストやドキュメントを記述するためのセル。
# - **特徴** :
#   - Markdown記法を使用して、見出し、リスト、リンク、画像、数式（LaTeX）などを記述できます。
#   - プログラムコードの説明やドキュメントを作成する際に使用。
# - **例** :
#   ```markdown
#   # タイトル
#   - リスト項目1
#   - リスト項目2
#   **太字**や*斜体*の装飾が可能。
#   ```

# %% [markdown]
# ## 簡単な例
# ### Pythonコードセル,出力セルの例

# %%
# Pythonコードセル
# 2つの数値を足す例
a = 10
b = 20
print(f"{a+b=}")
# Out:
# a+b=30

# %% [markdown]
# ### Markdownセルの例

# %% [markdown]
# ```markdown
# # Markdownセルの例
# ## 見出し
# - リスト
# - **強調文字**
# ```

# %% [markdown]
# ## データ可視化の例
# 以下は、Jupyter Notebookを使用してデータを可視化するシンプルな例です。
# NumPyを使ってデータを生成し、Matplotlibを使用してグラフを描画します。
# ※matplotlibとnumpyがインストールされていない場合は以下のセルを実行します。

# %%
# !pip3 install matplotlib numpy

# %%
import matplotlib.pyplot as plt
import numpy as np

# データ生成
x = np.linspace(0, 10, 100)
y = np.sin(x)

# グラフ描画
plt.plot(x, y)
plt.title("Sine Wave")
plt.show()

# %% [markdown]
# ---
# # Jupyter Notebook ショートカット集
# Jupyter Notebookで使える便利なショートカットの一覧です。
# 以下のショートカットを活用することで、作業効率を大幅に向上させることができます。
#
# | **ショートカットキー**      | **動作**                           | **説明**                                                                 |
# |--------------------------|-----------------------------------|-------------------------------------------------------------------------|
# | `Shift + Enter`          | セルを実行して次のセルに移動            | 現在のセルを実行し、次のセルにカーソルが移動します。                              |
# | `Ctrl + Enter`           | セルを実行してそのまま留まる            | 現在のセルを実行しますが、カーソルはそのまま現在のセルに留まります。                   |
# | `Alt + Enter`            | セルを実行して新しいセルを追加           | 現在のセルを実行した後、直下に新しいセルを追加します。                            |
# | `Esc` + `M`              | セルをMarkdownに変更                 | セルをMarkdownモードに切り替え、テキストや説明文を記述できるようにします。              |
# | `Esc` + `Y`              | セルをコードセルに変更                | セルをPythonコードを記述するモードに切り替えます。                             |
# | `B`                     | 下に新しいセルを追加                 | 現在のセルの直下に新しいセルを追加します。                                     |
# | `A`                     | 上に新しいセルを追加                 | 現在のセルの直上に新しいセルを追加します。                                     |
# | `D` + `D`               | セルを削除                        | 現在のセルを削除します。                                                |
# | `X`                     | セルをカット                        | 現在のセルをカット（切り取り）し、クリップボードに保存します。                       |
# | `C`                     | セルをコピー                       | 現在のセルをコピーし、クリップボードに保存します。                             |
# | `V`                     | カットまたはコピーしたセルを貼り付け       | カットまたはコピーしたセルを現在のセルの直下に貼り付けます。                         |
# | `Z`                     | アクションを元に戻す（Undo）            | 直前に行った操作を元に戻します。                                           |
# | `Shift + Z`             | アクションをやり直す（Redo）            | 元に戻した操作をやり直します。                                           |
#
# これらのショートカットを覚えると、Jupyter Notebookでの操作がよりスムーズになります。
